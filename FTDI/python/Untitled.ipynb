# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from board import Board
from main import buildCCode, createBoard, getBoards

# %%
# buildCCode(clean=True)
# createBoard(['1.0', '20190320'])
boards = getBoards()
# print(boards)
board = Board(boards.ID.values[0])
# board.measure()
board.getVoltageDelta()
# print(listTables('data/db.sqlite'))
# Out:
#                            label     delta relative delta
# 0           X1_POWER_MGTVCCAUX_N -0.251771      -0.139873
# 1             X1_POWER_MGTAVTT_S  -0.24256      -0.202133
# 2             X1_POWER_MGTAVCC_S -0.146324      -0.182905
# 3             X1_POWER_MGTAVCC_N -0.144565      -0.180707
# 4             X1_POWER_MGTAVTT_N -0.244739       -0.20395
# 5                X1_POWER_VCCAUX -0.239511      -0.133062
# 6                 X1_POWER_+1.8V -0.240309      -0.133505
# 7                 X1_POWER_+3.3V -0.220216     -0.0667322
# 8                  SERVICES+1.5V -0.248123      -0.165415
# 9                  SERVICES+1.0V -0.246501      -0.246501
# 10                 SERVICES+1.8V -0.222095      -0.123386
# 11                 SERVICES+3.3V -0.208911     -0.0633065
# 12                     5V_SCALED  -1.68771      -0.337542
# 13               X1_POWER_VCCINT  -0.19898      -0.248725
# 14          X1_POWER_MGTVCCAUC_S -0.252166      -0.140092
# 15       X1_POWER_+1.8V_ANALOGUE -0.253083      -0.140602
# 16          X0_POWER_MGTVCCAUC_N -0.237181      -0.131767
# 17       X0_POWER_+1.8V_ANALOGUE -0.233714      -0.129841
# 18          X0_POWER_MGTVCCAUC_S -0.234832      -0.130462
# 19               X0_POWER_VCCINT -0.195192       -0.24399
# 20                X0_POWER_+3.3V -0.209244     -0.0634073
# 21                 ARTIX_MGTAVTT -0.247949      -0.206624
# 22                 ARTIX_MGTAVCC -0.251161      -0.251161
# 23  SERVICES_POWER_STANDBY_+3.3V -0.207944     -0.0630134
# 24                      Not Used   2.43111            inf
# 25                    +12_SCALED  -8.61523      -0.717936
# 26                X0_POWER_+1.8V  -0.23818      -0.132322
# 27               X0_POWER_VCCAUX  -0.23389      -0.129939
# 28            X0_POWER_MGTAVTT_N -0.239263      -0.199386
# 29            X0_POWER_MGTAVCC_N  -0.14481      -0.181012
# 30            X0_POWER_MGTAVCC_S -0.145156      -0.181445
# 31            X0_POWER_MGTAVTT_S  -0.24506      -0.204217
